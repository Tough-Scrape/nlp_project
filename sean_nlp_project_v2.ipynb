# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import re
from requests import get
import time
import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords
import unicodedata

# %%
def get_urls(start_page,stop_page):
    pages = list(range(start_page,stop_page+1))
    page_urls = []
    for page in pages:
        p = f'https://github.com/search?o=desc&p={page}&q=stars%3A%3E1&s=stars&type=Repositories'
        page_urls.append(p)
    repo_links_all = []
    time.sleep(3)
    for page in page_urls:
        url = page
        headers  = {'User-Agent' : 'Codeup Data Science Student'} #user-agent to decrease chance of being rejected by github
        response = get(url,headers)
        soup = BeautifulSoup(response.text) #created a BS object
        repo_list = soup.find('ul', class_='repo-list') #find section of text of interest
        links = repo_list.find_all(href = True) #isolate the 'href's 
        repo_links= [link['href'] for link in links if not re.match(r'^/topics',link['href']) and not re.match(r'^https',link['href'])\
                 and link['href'].count('/') < 3] #further pare down list by excluding anything that begins with /topics, https or more than 2 forward slashes
        repo_links_all.extend(repo_links)
    repo_links_all = [url[1:] for url in repo_links_all]
    return repo_links_all

# %%
#urls = get_urls(1,7)

# %%
#urls2 = get_urls(8,14)

# %%
#urls3 = get_urls(15,22)

# %%
#repo_urls = urls + urls2 + urls3

# %%
# from env import github_token
# import os
# import json
# from typing import Dict, List
# import requests

# repos = url_list

# headers = {
#     "Authorization": f"token {github_token}",
#     "User-Agent": "soslin",
# }

# if (
#     headers["Authorization"] == "token "
#     or headers["User-Agent"] == "YOUR_GITHUB_USERNAME"
# ):
#     raise Exception(
#         "You need to follow the instructions marked TODO in this script before trying to use it"
#     )
# def github_api_request(url: str) -> requests.Response:
#     return requests.get(url, headers=headers)


# def get_repo_language(repo: str) -> str:
#     url = f"https://api.github.com/repos/{repo}"
#     return github_api_request(url).json()["language"]


# def get_repo_contents(repo: str) -> List[Dict[str, str]]:
#     url = f"https://api.github.com/repos/{repo}/contents/"
#     return github_api_request(url).json()


# def get_readme_download_url(files: List[Dict[str, str]]) -> str:
#     """
#     Takes in a response from the github api that lists
#     the files in a repo and returns the url that can be
#     used to download the repo's README file.
#     """
#     for file in files:
#         if file["name"].lower().startswith("readme"):
#             return file["download_url"]


# def process_repo(repo: str) -> Dict[str, str]:
#     """
#     Takes a repo name like "gocodeup/codeup-setup-script" and returns
#     a dictionary with the language of the repo and the readme contents.
#     """
#     contents = get_repo_contents(repo)
#     return {
#         "repo": repo,
#         "language": get_repo_language(repo),
#         "readme_contents": requests.get(get_readme_download_url(contents)).text,
#     }


# def scrape_github_data():
#     """
#     Loop through all of the repos and process them. Saves the data in
#     `data.json`.
#     """
#     data = [process_repo(repo) for repo in repos]
#     json.dump(data, open("data.json", "w"))



# scrape = scrape_github_data()

# %%
df = pd.read_json('data.json')

# %%
df
# Out:
#              language                                    readme_contents  \
# 0          JavaScript  ![freeCodeCamp.org Social Banner](https://s3.a...
# 1                Rust  [996.ICU](https://996.icu/#/en_US)\n=======\n*...
# 2          JavaScript  <p align="center"><a href="https://vuejs.org" ...
# 3          JavaScript  # [React](https://reactjs.org/) &middot; [![Gi...
# 4                 C++  <div align="center">\n  <img src="https://www....
# 5          JavaScript  <p align="center">\n  <a href="https://getboot...
# 6                None  This page is available as an easy-to-read webs...
# 7                None  <div align="center">\n\t<img width="500" heigh...
# 8                None  # You Don't Know JS Yet (book series) - 2nd Ed...
# 9               Shell  <p align="center">\n  <img src="https://s3.ama...
# 10               None  # Coding Interview University\n\n> I originall...
# 11               None  # A collection of `.gitignore` templates\n\nTh...
# 12               None  ![Web Developer Roadmap - 2019](https://i.imgu...
# 13         JavaScript  # Airbnb JavaScript Style Guide() {\n\n*A most...
# 14         JavaScript  # D3: Data-Driven Documents\n\n<a href="https:...
# 15         TypeScript  # Visual Studio Code - Open Source ("Code - OS...
# 16               Java  <div align="center">\n    <a href="https://git...
# 17                  C  Linux kernel\n============\n\nThere are severa...
# 18         JavaScript  <h1 align="center">\n  <a href="https://facebo...
# 19               Dart  # [![Flutter logo][]][flutter.dev]\n\n[![Build...
# 20                C++  [![Electron Logo](https://electronjs.org/image...
# 21             Python  *[English](README.md) ∙ [日本語](README-ja.md) ∙ ...
# 22             Python  # Awesome Python [![Awesome](https://cdn.rawgi...
# 23         JavaScript  # Create React App [![Build Status](https://de...
# 24   Jupyter Notebook  ## Python - 100天从新手到大师\n\n> 作者：骆昊\n>\n> 最近有很多想...
# 25         JavaScript  # axios\n\n[![npm version](https://img.shields...
# 26             Python  # Public APIs [![Build Status](https://api.tra...
# 27                 Go  # The Go Programming Language\n\nGo is an open...
# 28               None  🌍\n*[Čeština](README-cs.md) ∙ [Deutsch](README...
# 29         JavaScript  <p align="center">\n  <a href="https://nodejs....
# ..                ...                                                ...
# 190                Go  # Docker Container for Syncthing\n\nUse the Do...
# 191        JavaScript  <img src="https://raw.githubusercontent.com/he...
# 192              HTML  # [free-for.dev](https://free-for.dev)\n\nDeve...
# 193        JavaScript  # PDF.js [![Build Status](https://travis-ci.or...
# 194        JavaScript  Immutable collections for JavaScript\n========...
# 195              None  ﻿<h1 align="center">微信小程序开发资源汇总</h1>\n\n本文收集了微...
# 196        JavaScript  # fullPage.js\r\n![preview](https://raw.github...
# 197        JavaScript  <p>\n  <a href="http://badge.fury.io/js/jest">...
# 198            Python  # You-Get\n\n[![PyPI version](https://img.shie...
# 199                Go  # etcd\n\n[![Go Report Card](https://goreportc...
# 200        JavaScript  <p align="center">\n  <img src="https://raw.gi...
# 201              HTML  <p align="center">\n  <a href="http://foundati...
# 202            Python  This is Python version 3.9.0 alpha 1\n========...
# 203                Go  # Prometheus\n\n[![CircleCI](https://circleci....
# 204        JavaScript  <img src="/docs/logo.png" alt="Koa middleware ...
# 205        JavaScript  PixiJS — The HTML5 Creation Engine\n==========...
# 206              None  # Homebrew (Legacy)\n\nThis repository was dep...
# 207              Java  Glide\n=====\n\n[![Maven Central](https://mave...
# 208            Python  # deepfakes_faceswap\n<p align="center">\n  <a...
# 209            Kotlin  ## [Shadowsocks](https://shadowsocks.org) for ...
# 210              Ruby  <h3 align="center">\n  <a href="https://github...
# 211        JavaScript  # clipboard.js\n\n[![Build Status](http://img....
# 212              Java  # Lottie for Android, [iOS](https://github.com...
# 213              None  # Project Based Learning\n\nA list of programm...
# 214        JavaScript       ____                     __      __\n    ...
# 215        JavaScript  <p>\n  <a href="https://svelte.dev">\n\t<img a...
# 216        JavaScript  # Algorithm Visualizer\n\n> Algorithm Visualiz...
# 217        JavaScript  # clean-code-javascript\n\n## Table of Content...
# 218               TeX  # Deep Learning 中文翻译\n\n在众多网友的帮助和校对下，中文版终于出版了。...
# 219            Python  # 100-Days-Of-ML-Code\n\n100 Days of Machine L...
#
#                                           repo
# 0                    freeCodeCamp/freeCodeCamp
# 1                               996icu/996.ICU
# 2                                    vuejs/vue
# 3                               facebook/react
# 4                        tensorflow/tensorflow
# 5                               twbs/bootstrap
# 6       EbookFoundation/free-programming-books
# 7                         sindresorhus/awesome
# 8                      getify/You-Dont-Know-JS
# 9                              ohmyzsh/ohmyzsh
# 10         jwasham/coding-interview-university
# 11                            github/gitignore
# 12             kamranahmedse/developer-roadmap
# 13                           airbnb/javascript
# 14                                       d3/d3
# 15                            microsoft/vscode
# 16                            CyC2018/CS-Notes
# 17                              torvalds/linux
# 18                       facebook/react-native
# 19                             flutter/flutter
# 20                           electron/electron
# 21            donnemartin/system-design-primer
# 22                        vinta/awesome-python
# 23                   facebook/create-react-app
# 24                   jackfrued/Python-100-Days
# 25                                 axios/axios
# 26                     public-apis/public-apis
# 27                                   golang/go
# 28               jlevy/the-art-of-command-line
# 29                                 nodejs/node
# ..                                         ...
# 190                        syncthing/syncthing
# 191                                hexojs/hexo
# 192                     ripienaar/free-for-dev
# 193                             mozilla/pdf.js
# 194                  immutable-js/immutable-js
# 195             justjavac/awesome-wechat-weapp
# 196                    alvarotrigo/fullPage.js
# 197                              facebook/jest
# 198                            soimort/you-get
# 199                               etcd-io/etcd
# 200                            slatedocs/slate
# 201                foundation/foundation-sites
# 202                             python/cpython
# 203                      prometheus/prometheus
# 204                                  koajs/koa
# 205                             pixijs/pixi.js
# 206                   Homebrew/legacy-homebrew
# 207                             bumptech/glide
# 208                         deepfakes/faceswap
# 209            shadowsocks/shadowsocks-android
# 210                          fastlane/fastlane
# 211                     zenorocha/clipboard.js
# 212                      airbnb/lottie-android
# 213             tuvtran/project-based-learning
# 214                         jashkenas/backbone
# 215                            sveltejs/svelte
# 216  algorithm-visualizer/algorithm-visualizer
# 217        ryanmcdermott/clean-code-javascript
# 218           exacity/deeplearningbook-chinese
# 219              Avik-Jain/100-Days-Of-ML-Code
#
# [220 rows x 3 columns]

# %%
def basic_clean(string):
    """
    Lowercase the string
    Normalize unicode characters
    Replace anything that is not a letter, number, whitespace or a single quote.
    """
    string = string.lower()
    string = unicodedata.normalize('NFKD', string).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    
    # remove anything not a space character, an apostrophy, letter, or number
    string = re.sub(r"[^a-z0-9'\s]", '', string)

    # convert newlines and tabs to a single space
    string = re.sub(r'[\r|\n|\r\n]+', ' ', string)
    
    string = string.strip()
    return string

# %%
df2 = df.copy()
df2.head()
# Out:
#      language                                    readme_contents  \
# 0  JavaScript  ![freeCodeCamp.org Social Banner](https://s3.a...
# 1        Rust  [996.ICU](https://996.icu/#/en_US)\n=======\n*...
# 2  JavaScript  <p align="center"><a href="https://vuejs.org" ...
# 3  JavaScript  # [React](https://reactjs.org/) &middot; [![Gi...
# 4         C++  <div align="center">\n  <img src="https://www....
#
#                         repo
# 0  freeCodeCamp/freeCodeCamp
# 1             996icu/996.ICU
# 2                  vuejs/vue
# 3             facebook/react
# 4      tensorflow/tensorflow

# %%
df2.set_index('repo', inplace = True)

# %%
df2.readme_contents = df2.readme_contents.apply(basic_clean)

# %%
df2.head()
# Out:
#                              language  \
# repo
# freeCodeCamp/freeCodeCamp  JavaScript
# 996icu/996.ICU                   Rust
# vuejs/vue                  JavaScript
# facebook/react             JavaScript
# tensorflow/tensorflow             C++
#
#                                                              readme_contents
# repo
# freeCodeCamp/freeCodeCamp  freecodecamporg social bannerhttpss3amazonawsc...
# 996icu/996.ICU             996icuhttps996icuenus please note that there e...
# vuejs/vue                  p aligncentera hrefhttpsvuejsorg targetblank r...
# facebook/react             reacthttpsreactjsorg middot github licensehttp...
# tensorflow/tensorflow      div aligncenter   img srchttpswwwtensorfloworg...

# %%
def tokenize(s):
    tokenizer = nltk.tokenize.ToktokTokenizer()
    return tokenizer.tokenize(s, return_str=True)

# %%
df2.readme_contents.apply(tokenize)
# Out:
# repo
# freeCodeCamp/freeCodeCamp                    freecodecamporg social bannerhttpss3amazonawsc...
# 996icu/996.ICU                               996icuhttps996icuenus please note that there e...
# vuejs/vue                                    p aligncentera hrefhttpsvuejsorg targetblank r...
# facebook/react                               reacthttpsreactjsorg middot github licensehttp...
# tensorflow/tensorflow                        div aligncenter img srchttpswwwtensorfloworgim...
# twbs/bootstrap                               p aligncenter a hrefhttpsgetbootstrapcom img s...
# EbookFoundation/free-programming-books       this page is available as an easytoread websit...
# sindresorhus/awesome                         div aligncenter &#9; img width500 height350 sr...
# getify/You-Dont-Know-JS                      you don ' t know js yet book series 2nd editio...
# ohmyzsh/ohmyzsh                              p aligncenter img srchttpss3amazonawscomohmyzs...
# jwasham/coding-interview-university          coding interview university i originally creat...
# github/gitignore                             a collection of gitignore templates this is gi...
# kamranahmedse/developer-roadmap              web developer roadmap 2019httpsiimgurcoms5ccv9...
# airbnb/javascript                            airbnb javascript style guide a mostly reasona...
# d3/d3                                        d3 datadriven documents a hrefhttpsd3jsorgimg ...
# microsoft/vscode                             visual studio code open source code oss build ...
# CyC2018/CS-Notes                             div aligncenter a hrefhttpsgitstarrankingcomre...
# torvalds/linux                               linux kernel there are several guides for kern...
# facebook/react-native                        h1 aligncenter a hrefhttpsfacebookgithubioreac...
# flutter/flutter                              flutter logoflutterdev build status cirrusbuil...
# electron/electron                            electron logohttpselectronjsorgimageselectronl...
# donnemartin/system-design-primer             englishreadmemd readmejamd readmezhhansmd read...
# vinta/awesome-python                         awesome python awesomehttpscdnrawgitcomsindres...
# facebook/create-react-app                    create react app build statushttpsdevazurecomf...
# jackfrued/Python-100-Days                    python 100 pythonpythonpython15101510python100...
# axios/axios                                  axios npm versionhttpsimgshieldsionpmvaxiossvg...
# public-apis/public-apis                      public apis build statushttpsapitravisciorgpub...
# golang/go                                    the go programming language go is an open sour...
# jlevy/the-art-of-command-line                cestinareadmecsmd deutschreadmedemd readmeelmd...
# nodejs/node                                  p aligncenter a hrefhttpsnodejsorg img altnode...
#                                                                    ...
# syncthing/syncthing                          docker container for syncthing use the dockerf...
# hexojs/hexo                                  img srchttpsrawgithubusercontentcomhexojslogom...
# ripienaar/free-for-dev                       freefordevhttpsfreefordev developers and open ...
# mozilla/pdf.js                               pdfjs build statushttpstravisciorgmozillapdfjs...
# immutable-js/immutable-js                    immutable collections for javascript build sta...
# justjavac/awesome-wechat-weapp               h1 aligncenterh1 httpsgithubcomjustjavacawesom...
# alvarotrigo/fullPage.js                      fullpagejs previewhttpsrawgithubcomalvarotrigo...
# facebook/jest                                p a hrefhttpbadgefuryiojsjestimg srchttpsbadge...
# soimort/you-get                              youget pypi versionhttpsimgshieldsiopypivyouge...
# etcd-io/etcd                                 etcd go report cardhttpsgoreportcardcombadgegi...
# slatedocs/slate                              p aligncenter img srchttpsrawgithubusercontent...
# foundation/foundation-sites                  p aligncenter a hrefhttpfoundationzurbcom img ...
# python/cpython                               this is python version 390 alpha 1 image https...
# prometheus/prometheus                        prometheus circlecihttpscirclecicomghprometheu...
# koajs/koa                                    img srcdocslogopng altkoa middleware framework...
# pixijs/pixi.js                               pixijs the html5 creation engine pixijs logoht...
# Homebrew/legacy-homebrew                     homebrew legacy this repository was deprecated...
# bumptech/glide                               glide maven centralhttpsmavenbadgesherokuappco...
# deepfakes/faceswap                           deepfakesfaceswap p aligncenter a hrefhttpsfac...
# shadowsocks/shadowsocks-android              shadowsockshttpsshadowsocksorg for android cir...
# fastlane/fastlane                            h3 aligncenter a hrefhttpsgithubcomfastlanefas...
# zenorocha/clipboard.js                       clipboardjs build statushttpimgshieldsiotravis...
# airbnb/lottie-android                        lottie for android ioshttpsgithubcomairbnblott...
# tuvtran/project-based-learning               project based learning a list of programming t...
# jashkenas/backbone                           ' ' ' ' ' ' ' ' ' ' backbone supplies structur...
# sveltejs/svelte                              p a hrefhttpssveltedev &#9; img altcybernetica...
# algorithm-visualizer/algorithm-visualizer    algorithm visualizer algorithm visualizer is a...
# ryanmcdermott/clean-code-javascript          cleancodejavascript table of contents 1 introd...
# exacity/deeplearningbook-chinese             deep learning 90 deep learninghttpwwwdeeplearn...
# Avik-Jain/100-Days-Of-ML-Code                100daysofmlcode 100 days of machine learning c...
# Name: readme_contents, Length: 220, dtype: object

# %%
def stem(s):
    ps = nltk.porter.PorterStemmer()
    stems = [ps.stem(word) for word in s.split()]
    string_of_stems = ' '.join(stems)
    return string_of_stems

# %%
df2.readme_contents = df2.readme_contents.apply(stem)

# %%
def lemmatize(s):
    wnl = nltk.stem.WordNetLemmatizer()
    lemmas = [wnl.lemmatize(word) for word in s.split()]
    string_of_lemmas = ' '.join(lemmas)
    return string_of_lemmas

# %%
df2.readme_contents = df2.readme_contents.apply(lemmatize)

# %%
def remove_stopwords(s,extra_words =[], exclude_words = []):
    #Tokenize the string
    s = tokenize(s)
    
    words = s.split()
    stopword_list = stopwords.words('english')
    
    #remove the excluded words from the stopword list
    stopword_list = set(stopword_list) - set(exclude_words)
    
    #add in the user specified extra words
    stopword_list = stopword_list.union(set(extra_words))
    
    filtered_words = [w for w in words if w not in stopword_list]
    final_string = ' '.join(filtered_words)
    return final_string

# %%
stopwords_list = ['&#9;', 'data', 'source', 'use']
words_to_exclude = []

# %%
def prep_urls(df2):
    df2['original'] = df2.readme_contents
    df2['stemmed'] = df2.readme_contents.apply(basic_clean).apply(stem).apply(remove_stopwords)
    df2['lemmatized'] = df2.readme_contents.apply(basic_clean).apply(lemmatize).apply(remove_stopwords)
    df2['clean'] = df2.readme_contents.apply(basic_clean).apply(remove_stopwords)
    return df2

# %%
prep_urls(df2)
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#                                                    language  \
# repo
# freeCodeCamp/freeCodeCamp                        JavaScript
# 996icu/996.ICU                                         Rust
# vuejs/vue                                        JavaScript
# facebook/react                                   JavaScript
# tensorflow/tensorflow                                   C++
# twbs/bootstrap                                   JavaScript
# ohmyzsh/ohmyzsh                                       Shell
# airbnb/javascript                                JavaScript
# d3/d3                                            JavaScript
# microsoft/vscode                                 TypeScript
# CyC2018/CS-Notes                                       Java
# torvalds/linux                                            C
# facebook/react-native                            JavaScript
# flutter/flutter                                        Dart
# electron/electron                                       C++
# donnemartin/system-design-primer                     Python
# vinta/awesome-python                                 Python
# facebook/create-react-app                        JavaScript
# jackfrued/Python-100-Days                  Jupyter Notebook
# axios/axios                                      JavaScript
# public-apis/public-apis                              Python
# golang/go                                                Go
# nodejs/node                                      JavaScript
# Snailclimb/JavaGuide                                   Java
# TheAlgorithms/Python                                 Python
# daneden/animate.css                                     CSS
# FortAwesome/Font-Awesome                         JavaScript
# kubernetes/kubernetes                                    Go
# tensorflow/models                                    Python
# angular/angular.js                               JavaScript
# ...                                                     ...
# PhilJay/MPAndroidChart                                 Java
# XX-net/XX-Net                                        Python
# sahat/hackathon-starter                          JavaScript
# syncthing/syncthing                                      Go
# hexojs/hexo                                      JavaScript
# ripienaar/free-for-dev                                 HTML
# mozilla/pdf.js                                   JavaScript
# immutable-js/immutable-js                        JavaScript
# alvarotrigo/fullPage.js                          JavaScript
# facebook/jest                                    JavaScript
# soimort/you-get                                      Python
# etcd-io/etcd                                             Go
# slatedocs/slate                                  JavaScript
# foundation/foundation-sites                            HTML
# python/cpython                                       Python
# prometheus/prometheus                                    Go
# koajs/koa                                        JavaScript
# pixijs/pixi.js                                   JavaScript
# bumptech/glide                                         Java
# deepfakes/faceswap                                   Python
# shadowsocks/shadowsocks-android                      Kotlin
# fastlane/fastlane                                      Ruby
# zenorocha/clipboard.js                           JavaScript
# airbnb/lottie-android                                  Java
# jashkenas/backbone                               JavaScript
# sveltejs/svelte                                  JavaScript
# algorithm-visualizer/algorithm-visualizer        JavaScript
# ryanmcdermott/clean-code-javascript              JavaScript
# exacity/deeplearningbook-chinese                        TeX
# Avik-Jain/100-Days-Of-ML-Code                        Python
#
#                                                                              readme_contents  \
# repo
# freeCodeCamp/freeCodeCamp                  freecodecamporg social bannerhttpss3amazonawsc...
# 996icu/996.ICU                             996icuhttps996icuenu plea note that there exis...
# vuejs/vue                                  p aligncentera hrefhttpsvuejsorg targetblank r...
# facebook/react                             reacthttpsreactjsorg middot github licensehttp...
# tensorflow/tensorflow                      div aligncent img srchttpswwwtensorfloworgimag...
# twbs/bootstrap                             p aligncent a hrefhttpsgetbootstrapcom img src...
# ohmyzsh/ohmyzsh                            p aligncent img srchttpss3amazonawscomohmyzsho...
# airbnb/javascript                          airbnb javascript style guid a mostli reason a...
# d3/d3                                      d3 datadriven document a hrefhttpsd3jsorgimg s...
# microsoft/vscode                           visual studio code open sourc code os build st...
# CyC2018/CS-Notes                           div aligncent a hrefhttpsgitstarrankingcomrepo...
# torvalds/linux                             linux kernel there are sever guid for kernel d...
# facebook/react-native                      h1 aligncent a hrefhttpsfacebookgithubioreactn...
# flutter/flutter                            flutter logoflutterdev build statu cirrusbuild...
# electron/electron                          electron logohttpselectronjsorgimageselectronl...
# donnemartin/system-design-primer           englishreadmemd readmejamd readmezhhansmd read...
# vinta/awesome-python                       awesom python awesomehttpscdnrawgitcomsindreso...
# facebook/create-react-app                  creat react app build statushttpsdevazurecomfa...
# jackfrued/Python-100-Days                  python 100 pythonpythonpython15101510python100...
# axios/axios                                axio npm versionhttpsimgshieldsionpmvaxiossvgs...
# public-apis/public-apis                    public api build statushttpsapitravisciorgpubl...
# golang/go                                  the go program languag go is an open sourc pro...
# nodejs/node                                p aligncent a hrefhttpsnodejsorg img altnodej ...
# Snailclimb/JavaGuide                       javajava 1211 ec 1 2g 89httpswwwaliyuncomminis...
# TheAlgorithms/Python                       the algorithm python donatehttpsimgshieldsioba...
# daneden/animate.css                        animatecss github releasehttpsimgshieldsiogith...
# FortAwesome/Font-Awesome                   h1img srchttpsimgfortawesomecom349cfdf6logofaf...
# kubernetes/kubernetes                      kubernet godoc widgetgodoc cii best practicesh...
# tensorflow/models                          tensorflow model thi repositori contain a numb...
# angular/angular.js                         use angularj with the closur compil the closur...
# ...                                                                                      ...
# PhilJay/MPAndroidChart                     bannerhttpsrawgithubcomphiljaympchartmasterdes...
# XX-net/XX-Net                              xxnet httpsgithubcomxxnetxxnetwikie4b8ade69687...
# sahat/hackathon-starter                    httpslh4googleusercontentcompvwzum9vv8uuweh51o...
# syncthing/syncthing                        docker contain for syncth use the dockerfil in...
# hexojs/hexo                                img srchttpsrawgithubusercontentcomhexojslogom...
# ripienaar/free-for-dev                     freefordevhttpsfreefordev develop and open sou...
# mozilla/pdf.js                             pdfj build statushttpstravisciorgmozillapdfjss...
# immutable-js/immutable-js                  immut collect for javascript build statushttps...
# alvarotrigo/fullPage.js                    fullpagej previewhttpsrawgithubcomalvarotrigof...
# facebook/jest                              p a hrefhttpbadgefuryiojsjestimg srchttpsbadge...
# soimort/you-get                            youget pypi versionhttpsimgshieldsiopypivyouge...
# etcd-io/etcd                               etcd go report cardhttpsgoreportcardcombadgegi...
# slatedocs/slate                            p aligncent img srchttpsrawgithubusercontentco...
# foundation/foundation-sites                p aligncent a hrefhttpfoundationzurbcom img sr...
# python/cpython                             thi is python version 390 alpha 1 imag httpstr...
# prometheus/prometheus                      prometheu circlecihttpscirclecicomghprometheus...
# koajs/koa                                  img srcdocslogopng altkoa middlewar framework ...
# pixijs/pixi.js                             pixij the html5 creation engin pixij logohttps...
# bumptech/glide                             glide maven centralhttpsmavenbadgesherokuappco...
# deepfakes/faceswap                         deepfakesfaceswap p aligncent a hrefhttpsfaces...
# shadowsocks/shadowsocks-android            shadowsockshttpsshadowsocksorg for android cir...
# fastlane/fastlane                          h3 aligncent a hrefhttpsgithubcomfastlanefastl...
# zenorocha/clipboard.js                     clipboardj build statushttpimgshieldsiotravisz...
# airbnb/lottie-android                      lotti for android ioshttpsgithubcomairbnblotti...
# jashkenas/backbone                         ' ' ' ' ' ' ' ' '' backbon suppli structur to ...
# sveltejs/svelte                            p a hrefhttpssveltedev img altcybernet enhanc ...
# algorithm-visualizer/algorithm-visualizer  algorithm visual algorithm visual is an intera...
# ryanmcdermott/clean-code-javascript        cleancodejavascript tabl of content 1 introduc...
# exacity/deeplearningbook-chinese           deep learn 90 deep learninghttpwwwdeeplearning...
# Avik-Jain/100-Days-Of-ML-Code              100daysofmlcod 100 day of machin learn code a ...
#
#                                                                                     original  \
# repo
# freeCodeCamp/freeCodeCamp                  freecodecamporg social bannerhttpss3amazonawsc...
# 996icu/996.ICU                             996icuhttps996icuenu plea note that there exis...
# vuejs/vue                                  p aligncentera hrefhttpsvuejsorg targetblank r...
# facebook/react                             reacthttpsreactjsorg middot github licensehttp...
# tensorflow/tensorflow                      div aligncent img srchttpswwwtensorfloworgimag...
# twbs/bootstrap                             p aligncent a hrefhttpsgetbootstrapcom img src...
# ohmyzsh/ohmyzsh                            p aligncent img srchttpss3amazonawscomohmyzsho...
# airbnb/javascript                          airbnb javascript style guid a mostli reason a...
# d3/d3                                      d3 datadriven document a hrefhttpsd3jsorgimg s...
# microsoft/vscode                           visual studio code open sourc code os build st...
# CyC2018/CS-Notes                           div aligncent a hrefhttpsgitstarrankingcomrepo...
# torvalds/linux                             linux kernel there are sever guid for kernel d...
# facebook/react-native                      h1 aligncent a hrefhttpsfacebookgithubioreactn...
# flutter/flutter                            flutter logoflutterdev build statu cirrusbuild...
# electron/electron                          electron logohttpselectronjsorgimageselectronl...
# donnemartin/system-design-primer           englishreadmemd readmejamd readmezhhansmd read...
# vinta/awesome-python                       awesom python awesomehttpscdnrawgitcomsindreso...
# facebook/create-react-app                  creat react app build statushttpsdevazurecomfa...
# jackfrued/Python-100-Days                  python 100 pythonpythonpython15101510python100...
# axios/axios                                axio npm versionhttpsimgshieldsionpmvaxiossvgs...
# public-apis/public-apis                    public api build statushttpsapitravisciorgpubl...
# golang/go                                  the go program languag go is an open sourc pro...
# nodejs/node                                p aligncent a hrefhttpsnodejsorg img altnodej ...
# Snailclimb/JavaGuide                       javajava 1211 ec 1 2g 89httpswwwaliyuncomminis...
# TheAlgorithms/Python                       the algorithm python donatehttpsimgshieldsioba...
# daneden/animate.css                        animatecss github releasehttpsimgshieldsiogith...
# FortAwesome/Font-Awesome                   h1img srchttpsimgfortawesomecom349cfdf6logofaf...
# kubernetes/kubernetes                      kubernet godoc widgetgodoc cii best practicesh...
# tensorflow/models                          tensorflow model thi repositori contain a numb...
# angular/angular.js                         use angularj with the closur compil the closur...
# ...                                                                                      ...
# PhilJay/MPAndroidChart                     bannerhttpsrawgithubcomphiljaympchartmasterdes...
# XX-net/XX-Net                              xxnet httpsgithubcomxxnetxxnetwikie4b8ade69687...
# sahat/hackathon-starter                    httpslh4googleusercontentcompvwzum9vv8uuweh51o...
# syncthing/syncthing                        docker contain for syncth use the dockerfil in...
# hexojs/hexo                                img srchttpsrawgithubusercontentcomhexojslogom...
# ripienaar/free-for-dev                     freefordevhttpsfreefordev develop and open sou...
# mozilla/pdf.js                             pdfj build statushttpstravisciorgmozillapdfjss...
# immutable-js/immutable-js                  immut collect for javascript build statushttps...
# alvarotrigo/fullPage.js                    fullpagej previewhttpsrawgithubcomalvarotrigof...
# facebook/jest                              p a hrefhttpbadgefuryiojsjestimg srchttpsbadge...
# soimort/you-get                            youget pypi versionhttpsimgshieldsiopypivyouge...
# etcd-io/etcd                               etcd go report cardhttpsgoreportcardcombadgegi...
# slatedocs/slate                            p aligncent img srchttpsrawgithubusercontentco...
# foundation/foundation-sites                p aligncent a hrefhttpfoundationzurbcom img sr...
# python/cpython                             thi is python version 390 alpha 1 imag httpstr...
# prometheus/prometheus                      prometheu circlecihttpscirclecicomghprometheus...
# koajs/koa                                  img srcdocslogopng altkoa middlewar framework ...
# pixijs/pixi.js                             pixij the html5 creation engin pixij logohttps...
# bumptech/glide                             glide maven centralhttpsmavenbadgesherokuappco...
# deepfakes/faceswap                         deepfakesfaceswap p aligncent a hrefhttpsfaces...
# shadowsocks/shadowsocks-android            shadowsockshttpsshadowsocksorg for android cir...
# fastlane/fastlane                          h3 aligncent a hrefhttpsgithubcomfastlanefastl...
# zenorocha/clipboard.js                     clipboardj build statushttpimgshieldsiotravisz...
# airbnb/lottie-android                      lotti for android ioshttpsgithubcomairbnblotti...
# jashkenas/backbone                         ' ' ' ' ' ' ' ' '' backbon suppli structur to ...
# sveltejs/svelte                            p a hrefhttpssveltedev img altcybernet enhanc ...
# algorithm-visualizer/algorithm-visualizer  algorithm visual algorithm visual is an intera...
# ryanmcdermott/clean-code-javascript        cleancodejavascript tabl of content 1 introduc...
# exacity/deeplearningbook-chinese           deep learn 90 deep learninghttpwwwdeeplearning...
# Avik-Jain/100-Days-Of-ML-Code              100daysofmlcod 100 day of machin learn code a ...
#
#                                                                                      stemmed  \
# repo
# freeCodeCamp/freeCodeCamp                  freecodecamporg social bannerhttpss3amazonawsc...
# 996icu/996.ICU                             996icuhttps996icuenu plea note exist offici ac...
# vuejs/vue                                  p aligncentera hrefhttpsvuejsorg targetblank r...
# facebook/react                             reacthttpsreactjsorg middot github licensehttp...
# tensorflow/tensorflow                      div alignc img srchttpswwwtensorfloworgimagest...
# twbs/bootstrap                             p alignc hrefhttpsgetbootstrapcom img srchttps...
# ohmyzsh/ohmyzsh                            p alignc img srchttpss3amazonawscomohmyzshohmy...
# airbnb/javascript                          airbnb javascript style guid mostli reason app...
# d3/d3                                      d3 datadriven document hrefhttpsd3jsorgimg src...
# microsoft/vscode                           visual studio code open sourc code os build st...
# CyC2018/CS-Notes                           div alignc hrefhttpsgitstarrankingcomrepositor...
# torvalds/linux                             linux kernel sever guid kernel develop user gu...
# facebook/react-native                      h1 alignc hrefhttpsfacebookgithubioreactn reac...
# flutter/flutter                            flutter logoflutterdev build statu cirrusbuild...
# electron/electron                          electron logohttpselectronjsorgimageselectronl...
# donnemartin/system-design-primer           englishreadmemd readmejamd readmezhhansmd read...
# vinta/awesome-python                       awesom python awesomehttpscdnrawgitcomsindreso...
# facebook/create-react-app                  creat react app build statushttpsdevazurecomfa...
# jackfrued/Python-100-Days                  python 100 pythonpythonpython15101510python100...
# axios/axios                                axio npm versionhttpsimgshieldsionpmvaxiossvgs...
# public-apis/public-apis                    public api build statushttpsapitravisciorgpubl...
# golang/go                                  go program languag go open sourc program langu...
# nodejs/node                                p alignc hrefhttpsnodejsorg img altnodej srcht...
# Snailclimb/JavaGuide                       javajava 1211 ec 1 2g 89httpswwwaliyuncomminis...
# TheAlgorithms/Python                       algorithm python donatehttpsimgshieldsiobadged...
# daneden/animate.css                        animatecss github releasehttpsimgshieldsiogith...
# FortAwesome/Font-Awesome                   h1img srchttpsimgfortawesomecom349cfdf6logofaf...
# kubernetes/kubernetes                      kubernet godoc widgetgodoc cii best practicesh...
# tensorflow/models                          tensorflow model thi repositori contain number...
# angular/angular.js                         use angularj closur compil closur compil proje...
# ...                                                                                      ...
# PhilJay/MPAndroidChart                     bannerhttpsrawgithubcomphiljaympchartmasterdes...
# XX-net/XX-Net                              xxnet httpsgithubcomxxnetxxnetwikie4b8ade69687...
# sahat/hackathon-starter                    httpslh4googleusercontentcompvwzum9vv8uuweh51o...
# syncthing/syncthing                        docker contain syncth use dockerfil thi repo p...
# hexojs/hexo                                img srchttpsrawgithubusercontentcomhexojslogom...
# ripienaar/free-for-dev                     freefordevhttpsfreefordev develop open sourc a...
# mozilla/pdf.js                             pdfj build statushttpstravisciorgmozillapdfjss...
# immutable-js/immutable-js                  immut collect javascript build statushttpstrav...
# alvarotrigo/fullPage.js                    fullpagej previewhttpsrawgithubcomalvarotrigof...
# facebook/jest                              p hrefhttpbadgefuryiojsjestimg srchttpsbadgefu...
# soimort/you-get                            youget pypi versionhttpsimgshieldsiopypivyouge...
# etcd-io/etcd                               etcd go report cardhttpsgoreportcardcombadgegi...
# slatedocs/slate                            p alignc img srchttpsrawgithubusercontentcomlo...
# foundation/foundation-sites                p alignc hrefhttpfoundationzurbcom img srchttp...
# python/cpython                             thi python version 390 alpha 1 imag httpstravi...
# prometheus/prometheus                      prometheu circlecihttpscirclecicomghprometheus...
# koajs/koa                                  img srcdocslogopng altkoa middlewar framework ...
# pixijs/pixi.js                             pixij html5 creation engin pixij logohttpspixi...
# bumptech/glide                             glide maven centralhttpsmavenbadgesherokuappco...
# deepfakes/faceswap                         deepfakesfaceswap p alignc hrefhttpsfaceswapde...
# shadowsocks/shadowsocks-android            shadowsockshttpsshadowsocksorg android circlec...
# fastlane/fastlane                          h3 alignc hrefhttpsgithubcomfastlanefastlanebl...
# zenorocha/clipboard.js                     clipboardj build statushttpimgshieldsiotravisz...
# airbnb/lottie-android                      lotti android ioshttpsgithubcomairbnblottieio ...
# jashkenas/backbone                         ' ' ' ' ' ' ' ' ' ' backbon suppli structur ja...
# sveltejs/svelte                            p hrefhttpssveltedev img altcybernet enhanc we...
# algorithm-visualizer/algorithm-visualizer  algorithm visual algorithm visual interact onl...
# ryanmcdermott/clean-code-javascript        cleancodejavascript tabl content 1 introductio...
# exacity/deeplearningbook-chinese           deep learn 90 deep learninghttpwwwdeeplearning...
# Avik-Jain/100-Days-Of-ML-Code              100daysofmlcod 100 day machin learn code propo...
#
#                                                                                   lemmatized  \
# repo
# freeCodeCamp/freeCodeCamp                  freecodecamporg social bannerhttpss3amazonawsc...
# 996icu/996.ICU                             996icuhttps996icuenu plea note exist offici ac...
# vuejs/vue                                  p aligncentera hrefhttpsvuejsorg targetblank r...
# facebook/react                             reacthttpsreactjsorg middot github licensehttp...
# tensorflow/tensorflow                      div aligncent img srchttpswwwtensorfloworgimag...
# twbs/bootstrap                             p aligncent hrefhttpsgetbootstrapcom img srcht...
# ohmyzsh/ohmyzsh                            p aligncent img srchttpss3amazonawscomohmyzsho...
# airbnb/javascript                          airbnb javascript style guid mostli reason app...
# d3/d3                                      d3 datadriven document hrefhttpsd3jsorgimg src...
# microsoft/vscode                           visual studio code open sourc code build statu...
# CyC2018/CS-Notes                           div aligncent hrefhttpsgitstarrankingcomreposi...
# torvalds/linux                             linux kernel sever guid kernel develop user gu...
# facebook/react-native                      h1 aligncent hrefhttpsfacebookgithubioreactn r...
# flutter/flutter                            flutter logoflutterdev build statu cirrusbuild...
# electron/electron                          electron logohttpselectronjsorgimageselectronl...
# donnemartin/system-design-primer           englishreadmemd readmejamd readmezhhansmd read...
# vinta/awesome-python                       awesom python awesomehttpscdnrawgitcomsindreso...
# facebook/create-react-app                  creat react app build statushttpsdevazurecomfa...
# jackfrued/Python-100-Days                  python 100 pythonpythonpython15101510python100...
# axios/axios                                axio npm versionhttpsimgshieldsionpmvaxiossvgs...
# public-apis/public-apis                    public api build statushttpsapitravisciorgpubl...
# golang/go                                  go program languag go open sourc program langu...
# nodejs/node                                p aligncent hrefhttpsnodejsorg img altnodej sr...
# Snailclimb/JavaGuide                       javajava 1211 ec 1 2g 89httpswwwaliyuncomminis...
# TheAlgorithms/Python                       algorithm python donatehttpsimgshieldsiobadged...
# daneden/animate.css                        animatecss github releasehttpsimgshieldsiogith...
# FortAwesome/Font-Awesome                   h1img srchttpsimgfortawesomecom349cfdf6logofaf...
# kubernetes/kubernetes                      kubernet godoc widgetgodoc cii best practicesh...
# tensorflow/models                          tensorflow model thi repositori contain number...
# angular/angular.js                         use angularj closur compil closur compil proje...
# ...                                                                                      ...
# PhilJay/MPAndroidChart                     bannerhttpsrawgithubcomphiljaympchartmasterdes...
# XX-net/XX-Net                              xxnet httpsgithubcomxxnetxxnetwikie4b8ade69687...
# sahat/hackathon-starter                    httpslh4googleusercontentcompvwzum9vv8uuweh51o...
# syncthing/syncthing                        docker contain syncth use dockerfil thi repo p...
# hexojs/hexo                                img srchttpsrawgithubusercontentcomhexojslogom...
# ripienaar/free-for-dev                     freefordevhttpsfreefordev develop open sourc a...
# mozilla/pdf.js                             pdfj build statushttpstravisciorgmozillapdfjss...
# immutable-js/immutable-js                  immut collect javascript build statushttpstrav...
# alvarotrigo/fullPage.js                    fullpagej previewhttpsrawgithubcomalvarotrigof...
# facebook/jest                              p hrefhttpbadgefuryiojsjestimg srchttpsbadgefu...
# soimort/you-get                            youget pypi versionhttpsimgshieldsiopypivyouge...
# etcd-io/etcd                               etcd go report cardhttpsgoreportcardcombadgegi...
# slatedocs/slate                            p aligncent img srchttpsrawgithubusercontentco...
# foundation/foundation-sites                p aligncent hrefhttpfoundationzurbcom img srch...
# python/cpython                             thi python version 390 alpha 1 imag httpstravi...
# prometheus/prometheus                      prometheu circlecihttpscirclecicomghprometheus...
# koajs/koa                                  img srcdocslogopng altkoa middlewar framework ...
# pixijs/pixi.js                             pixij html5 creation engin pixij logohttpspixi...
# bumptech/glide                             glide maven centralhttpsmavenbadgesherokuappco...
# deepfakes/faceswap                         deepfakesfaceswap p aligncent hrefhttpsfaceswa...
# shadowsocks/shadowsocks-android            shadowsockshttpsshadowsocksorg android circlec...
# fastlane/fastlane                          h3 aligncent hrefhttpsgithubcomfastlanefastlan...
# zenorocha/clipboard.js                     clipboardj build statushttpimgshieldsiotravisz...
# airbnb/lottie-android                      lotti android ioshttpsgithubcomairbnblottieio ...
# jashkenas/backbone                         ' ' ' ' ' ' ' ' ' ' backbon suppli structur ja...
# sveltejs/svelte                            p hrefhttpssveltedev img altcybernet enhanc we...
# algorithm-visualizer/algorithm-visualizer  algorithm visual algorithm visual interact onl...
# ryanmcdermott/clean-code-javascript        cleancodejavascript tabl content 1 introductio...
# exacity/deeplearningbook-chinese           deep learn 90 deep learninghttpwwwdeeplearning...
# Avik-Jain/100-Days-Of-ML-Code              100daysofmlcod 100 day machin learn code propo...
#
#                                                                                        clean
# repo
# freeCodeCamp/freeCodeCamp                  freecodecamporg social bannerhttpss3amazonawsc...
# 996icu/996.ICU                             996icuhttps996icuenu plea note exist offici ac...
# vuejs/vue                                  p aligncentera hrefhttpsvuejsorg targetblank r...
# facebook/react                             reacthttpsreactjsorg middot github licensehttp...
# tensorflow/tensorflow                      div aligncent img srchttpswwwtensorfloworgimag...
# twbs/bootstrap                             p aligncent hrefhttpsgetbootstrapcom img srcht...
# ohmyzsh/ohmyzsh                            p aligncent img srchttpss3amazonawscomohmyzsho...
# airbnb/javascript                          airbnb javascript style guid mostli reason app...
# d3/d3                                      d3 datadriven document hrefhttpsd3jsorgimg src...
# microsoft/vscode                           visual studio code open sourc code os build st...
# CyC2018/CS-Notes                           div aligncent hrefhttpsgitstarrankingcomreposi...
# torvalds/linux                             linux kernel sever guid kernel develop user gu...
# facebook/react-native                      h1 aligncent hrefhttpsfacebookgithubioreactn r...
# flutter/flutter                            flutter logoflutterdev build statu cirrusbuild...
# electron/electron                          electron logohttpselectronjsorgimageselectronl...
# donnemartin/system-design-primer           englishreadmemd readmejamd readmezhhansmd read...
# vinta/awesome-python                       awesom python awesomehttpscdnrawgitcomsindreso...
# facebook/create-react-app                  creat react app build statushttpsdevazurecomfa...
# jackfrued/Python-100-Days                  python 100 pythonpythonpython15101510python100...
# axios/axios                                axio npm versionhttpsimgshieldsionpmvaxiossvgs...
# public-apis/public-apis                    public api build statushttpsapitravisciorgpubl...
# golang/go                                  go program languag go open sourc program langu...
# nodejs/node                                p aligncent hrefhttpsnodejsorg img altnodej sr...
# Snailclimb/JavaGuide                       javajava 1211 ec 1 2g 89httpswwwaliyuncomminis...
# TheAlgorithms/Python                       algorithm python donatehttpsimgshieldsiobadged...
# daneden/animate.css                        animatecss github releasehttpsimgshieldsiogith...
# FortAwesome/Font-Awesome                   h1img srchttpsimgfortawesomecom349cfdf6logofaf...
# kubernetes/kubernetes                      kubernet godoc widgetgodoc cii best practicesh...
# tensorflow/models                          tensorflow model thi repositori contain number...
# angular/angular.js                         use angularj closur compil closur compil proje...
# ...                                                                                      ...
# PhilJay/MPAndroidChart                     bannerhttpsrawgithubcomphiljaympchartmasterdes...
# XX-net/XX-Net                              xxnet httpsgithubcomxxnetxxnetwikie4b8ade69687...
# sahat/hackathon-starter                    httpslh4googleusercontentcompvwzum9vv8uuweh51o...
# syncthing/syncthing                        docker contain syncth use dockerfil thi repo p...
# hexojs/hexo                                img srchttpsrawgithubusercontentcomhexojslogom...
# ripienaar/free-for-dev                     freefordevhttpsfreefordev develop open sourc a...
# mozilla/pdf.js                             pdfj build statushttpstravisciorgmozillapdfjss...
# immutable-js/immutable-js                  immut collect javascript build statushttpstrav...
# alvarotrigo/fullPage.js                    fullpagej previewhttpsrawgithubcomalvarotrigof...
# facebook/jest                              p hrefhttpbadgefuryiojsjestimg srchttpsbadgefu...
# soimort/you-get                            youget pypi versionhttpsimgshieldsiopypivyouge...
# etcd-io/etcd                               etcd go report cardhttpsgoreportcardcombadgegi...
# slatedocs/slate                            p aligncent img srchttpsrawgithubusercontentco...
# foundation/foundation-sites                p aligncent hrefhttpfoundationzurbcom img srch...
# python/cpython                             thi python version 390 alpha 1 imag httpstravi...
# prometheus/prometheus                      prometheu circlecihttpscirclecicomghprometheus...
# koajs/koa                                  img srcdocslogopng altkoa middlewar framework ...
# pixijs/pixi.js                             pixij html5 creation engin pixij logohttpspixi...
# bumptech/glide                             glide maven centralhttpsmavenbadgesherokuappco...
# deepfakes/faceswap                         deepfakesfaceswap p aligncent hrefhttpsfaceswa...
# shadowsocks/shadowsocks-android            shadowsockshttpsshadowsocksorg android circlec...
# fastlane/fastlane                          h3 aligncent hrefhttpsgithubcomfastlanefastlan...
# zenorocha/clipboard.js                     clipboardj build statushttpimgshieldsiotravisz...
# airbnb/lottie-android                      lotti android ioshttpsgithubcomairbnblottieio ...
# jashkenas/backbone                         ' ' ' ' ' ' ' ' ' ' backbon suppli structur ja...
# sveltejs/svelte                            p hrefhttpssveltedev img altcybernet enhanc we...
# algorithm-visualizer/algorithm-visualizer  algorithm visual algorithm visual interact onl...
# ryanmcdermott/clean-code-javascript        cleancodejavascript tabl content 1 introductio...
# exacity/deeplearningbook-chinese           deep learn 90 deep learninghttpwwwdeeplearning...
# Avik-Jain/100-Days-Of-ML-Code              100daysofmlcod 100 day machin learn code propo...
#
# [188 rows x 6 columns]

# %%
df2.head()
# Out:
#                              language  \
# repo
# freeCodeCamp/freeCodeCamp  JavaScript
# 996icu/996.ICU                   Rust
# vuejs/vue                  JavaScript
# facebook/react             JavaScript
# tensorflow/tensorflow             C++
#
#                                                              readme_contents  \
# repo
# freeCodeCamp/freeCodeCamp  freecodecamporg social bannerhttpss3amazonawsc...
# 996icu/996.ICU             996icuhttps996icuenu plea note that there exis...
# vuejs/vue                  p aligncentera hrefhttpsvuejsorg targetblank r...
# facebook/react             reacthttpsreactjsorg middot github licensehttp...
# tensorflow/tensorflow      div aligncent img srchttpswwwtensorfloworgimag...
#
#                                                                     original  \
# repo
# freeCodeCamp/freeCodeCamp  freecodecamporg social bannerhttpss3amazonawsc...
# 996icu/996.ICU             996icuhttps996icuenu plea note that there exis...
# vuejs/vue                  p aligncentera hrefhttpsvuejsorg targetblank r...
# facebook/react             reacthttpsreactjsorg middot github licensehttp...
# tensorflow/tensorflow      div aligncent img srchttpswwwtensorfloworgimag...
#
#                                                                      stemmed  \
# repo
# freeCodeCamp/freeCodeCamp  freecodecamporg social bannerhttpss3amazonawsc...
# 996icu/996.ICU             996icuhttps996icuenu plea note exist offici ac...
# vuejs/vue                  p aligncentera hrefhttpsvuejsorg targetblank r...
# facebook/react             reacthttpsreactjsorg middot github licensehttp...
# tensorflow/tensorflow      div alignc img srchttpswwwtensorfloworgimagest...
#
#                                                                   lemmatized  \
# repo
# freeCodeCamp/freeCodeCamp  freecodecamporg social bannerhttpss3amazonawsc...
# 996icu/996.ICU             996icuhttps996icuenu plea note exist offici ac...
# vuejs/vue                  p aligncentera hrefhttpsvuejsorg targetblank r...
# facebook/react             reacthttpsreactjsorg middot github licensehttp...
# tensorflow/tensorflow      div aligncent img srchttpswwwtensorfloworgimag...
#
#                                                                        clean
# repo
# freeCodeCamp/freeCodeCamp  freecodecamporg social bannerhttpss3amazonawsc...
# 996icu/996.ICU             996icuhttps996icuenu plea note exist offici ac...
# vuejs/vue                  p aligncentera hrefhttpsvuejsorg targetblank r...
# facebook/react             reacthttpsreactjsorg middot github licensehttp...
# tensorflow/tensorflow      div aligncent img srchttpswwwtensorfloworgimag...

# %%
df2.describe()
# Out:
#           language                                    readme_contents  \
# count          188                                                188
# unique          25                                                188
# top     JavaScript  clipboardj build statushttpimgshieldsiotravisz...
# freq            72                                                  1
#
#                                                  original  \
# count                                                 188
# unique                                                188
# top     clipboardj build statushttpimgshieldsiotravisz...
# freq                                                    1
#
#                                                   stemmed  \
# count                                                 188
# unique                                                188
# top     gin web framework img alignright width159px sr...
# freq                                                    1
#
#                                                lemmatized  \
# count                                                 188
# unique                                                188
# top     fira code monospac font program ligatur img sr...
# freq                                                    1
#
#                                                     clean
# count                                                 188
# unique                                                188
# top     join chat httpsgitterimmomentmomenthttpsbadges...
# freq                                                    1

# %%
df2['repo2'] = df2.index
df2.head()
# Out:
#                              language  \
# repo
# freeCodeCamp/freeCodeCamp  JavaScript
# 996icu/996.ICU                   Rust
# vuejs/vue                  JavaScript
# facebook/react             JavaScript
# tensorflow/tensorflow             C++
#
#                                                              readme_contents  \
# repo
# freeCodeCamp/freeCodeCamp  freecodecamporg social bannerhttpss3amazonawsc...
# 996icu/996.ICU             996icuhttps996icuenu plea note that there exis...
# vuejs/vue                  p aligncentera hrefhttpsvuejsorg targetblank r...
# facebook/react             reacthttpsreactjsorg middot github licensehttp...
# tensorflow/tensorflow      div aligncent img srchttpswwwtensorfloworgimag...
#
#                                                                     original  \
# repo
# freeCodeCamp/freeCodeCamp  freecodecamporg social bannerhttpss3amazonawsc...
# 996icu/996.ICU             996icuhttps996icuenu plea note that there exis...
# vuejs/vue                  p aligncentera hrefhttpsvuejsorg targetblank r...
# facebook/react             reacthttpsreactjsorg middot github licensehttp...
# tensorflow/tensorflow      div aligncent img srchttpswwwtensorfloworgimag...
#
#                                                                      stemmed  \
# repo
# freeCodeCamp/freeCodeCamp  freecodecamporg social bannerhttpss3amazonawsc...
# 996icu/996.ICU             996icuhttps996icuenu plea note exist offici ac...
# vuejs/vue                  p aligncentera hrefhttpsvuejsorg targetblank r...
# facebook/react             reacthttpsreactjsorg middot github licensehttp...
# tensorflow/tensorflow      div alignc img srchttpswwwtensorfloworgimagest...
#
#                                                                   lemmatized  \
# repo
# freeCodeCamp/freeCodeCamp  freecodecamporg social bannerhttpss3amazonawsc...
# 996icu/996.ICU             996icuhttps996icuenu plea note exist offici ac...
# vuejs/vue                  p aligncentera hrefhttpsvuejsorg targetblank r...
# facebook/react             reacthttpsreactjsorg middot github licensehttp...
# tensorflow/tensorflow      div aligncent img srchttpswwwtensorfloworgimag...
#
#                                                                        clean  \
# repo
# freeCodeCamp/freeCodeCamp  freecodecamporg social bannerhttpss3amazonawsc...
# 996icu/996.ICU             996icuhttps996icuenu plea note exist offici ac...
# vuejs/vue                  p aligncentera hrefhttpsvuejsorg targetblank r...
# facebook/react             reacthttpsreactjsorg middot github licensehttp...
# tensorflow/tensorflow      div aligncent img srchttpswwwtensorfloworgimag...
#
#                                                repo2
# repo
# freeCodeCamp/freeCodeCamp  freeCodeCamp/freeCodeCamp
# 996icu/996.ICU                        996icu/996.ICU
# vuejs/vue                                  vuejs/vue
# facebook/react                        facebook/react
# tensorflow/tensorflow          tensorflow/tensorflow

# %%
df2.groupby('language').count().sort_values(by = 'repo2',ascending=False).head()
# Out:
#             readme_contents  original  stemmed  lemmatized  clean  repo2
# language
# JavaScript               72        72       72          72     72     72
# Python                   25        25       25          25     25     25
# Java                     17        17       17          17     17     17
# C++                      12        12       12          12     12     12
# Go                       12        12       12          12     12     12

# %%
corpus_complete = df2.clean.sum() #corpus is one big string
corpus_complete
# Out:
# "freecodecamporg social bannerhttpss3amazonawscomfreecodecampwidesocialbannerpng pull request welcomehttpsimgshieldsiobadgeprswelcomebrightgreensvgstyleflathttpmakeapullrequestcom firsttimersonli friendlyhttpsimgshieldsiobadgefirsttimersonlyfriendlybluesvghttpwwwfirsttimersonlycom open sourc helpershttpswwwcodetriagecomfreecodecampfreecodecampbadgesuserssvghttpswwwcodetriagecomfreecodecampfreecodecamp setup automatedhttpsimgshieldsiobadgesetupautomatedbluelogogitpodhttpsgitpodiofromreferr freecodecamporg ' opensourc codebas curriculum freecodecamporghttpswwwfreecodecamporg friendli commun learn code free run donorsupport 501c3 nonprofithttpsdonatefreecodecamporg help million busi adult transit tech commun ha alreadi help 10000 peopl get first develop job fullstack web develop curriculum complet free selfpac thousand interact code challeng help expand skill tabl content certificationscertif learn platformthelearningplatform report bug issuesreportingbugsandissu report secur issuesreportingsecurityissu contributingcontribut platform build deploy statusplatformbuildanddeploymentstatu licenselicens certif freecodecamporg offer sever free develop certif certif involv build 5 requir web app project along hundr option code challeng help prepar project estim certif take begin programm around 300 hour earn 30 project freecodecamporg curriculum ha agil user stori autom test help build project increment ensur ' v fulfil user stori befor submit pull test suit freecodecamp ' cdnhttpscdnfreecodecamporgtestableprojectsfccv1bundlej thi mean build project websit like codepen glitch even local computer ' develop environ onc youv earn certif alway alway abl link linkedin resum prospect employ freelanc client click link theyll see verifi certif specif one except thi discov violat academ honesti policyhttpswwwfreecodecamporgacademichonesti catch peopl unambigu plagiar submit people ' code project without citat rigor institut learn revok certif ban peopl six core certif 1 respons web design certif basic html html5httpslearnfreecodecamporgresponsivewebdesignbasichtmlandhtml5 basic csshttpslearnfreecodecamporgresponsivewebdesignbasiccss appli visual designhttpslearnfreecodecamporgresponsivewebdesignappliedvisualdesign appli accessibilityhttpslearnfreecodecamporgresponsivewebdesignappliedaccess respons web design principleshttpslearnfreecodecamporgresponsivewebdesignresponsivewebdesignprincipl cs flexboxhttpslearnfreecodecamporgresponsivewebdesigncssflexbox cs gridhttpslearnfreecodecamporgresponsivewebdesigncssgrid br br project tribut page survey form product land page technic document page person portfolio webpag 2 javascript algorithm data structur certif basic javascripthttpslearnfreecodecamporgjavascriptalgorithmsanddatastructuresbasicjavascript es6httpslearnfreecodecamporgjavascriptalgorithmsanddatastructureses6 regular expressionshttpslearnfreecodecamporgjavascriptalgorithmsanddatastructuresregularexpress debugginghttpslearnfreecodecamporgjavascriptalgorithmsanddatastructuresdebug basic data structureshttpslearnfreecodecamporgjavascriptalgorithmsanddatastructuresbasicdatastructur algorithm scriptinghttpslearnfreecodecamporgjavascriptalgorithmsanddatastructuresbasicalgorithmscript objectori programminghttpslearnfreecodecamporgjavascriptalgorithmsanddatastructuresobjectorientedprogram function programminghttpslearnfreecodecamporgjavascriptalgorithmsanddatastructuresfunctionalprogram intermedi algorithm scriptinghttpslearnfreecodecamporgjavascriptalgorithmsanddatastructuresintermediatealgorithmscript br br project palindrom checker roman numer convert caesar ' cipher telephon number valid cash regist 3 front end librari certif bootstraphttpslearnfreecodecamporgfrontendlibrariesbootstrap jqueryhttpslearnfreecodecamporgfrontendlibrariesjqueri sasshttpslearnfreecodecamporgfrontendlibrariessass reacthttpslearnfreecodecamporgfrontendlibrariesreact reduxhttpslearnfreecodecamporgfrontendlibrariesredux react reduxhttpslearnfreecodecamporgfrontendlibraries ...

# %% [markdown]
# #Individual corpus for top 5 languages

# %%
javascript_corpus = df2[df2.language == "JavaScript"].clean.sum()

# %%
python_corpus = df2[df2.language == "Python"].clean.sum()

# %%
java_corpus = df2[df2.language == "Java"].clean.sum()

# %%
c_double_plus = df2[df2.language == "C++"].clean.sum()

# %%
go = df2[df2.language == "Go"].clean.sum()

# %%
# def words(string):
#     return list(nltk.ngrams(string.split(),1))
